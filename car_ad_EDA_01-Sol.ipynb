# %% [markdown]
# ## 패키지 및 데이터 불러오기

# %%
import numpy as np   # numpy 패키지 불러오기 
import pandas as pd  # pandas 패키지 불러오기 
import matplotlib  # matplotlib 패키지 불러오기 
import matplotlib.pyplot as plt # 그래프 시각화를 위한 패키지 불러오기
import seaborn as sns  # seaborn 패키지 불러오기 
import warnings        # warings(경고 메시지 없애주는)패키지 불러오기 
from matplotlib import font_manager, rc  # matplotlib안 한글 깨짐 처리
import platform   # 현재 사용하고 있는 시스템 유형을 알려주는 패키지 
import plotly.express as px  # 더 나은 시각화를 위해 plotly 패키지 불러오기 

# 운영체제에 맞게 폰트 설정
if platform.system() == "Windows":
    # 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgubn.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')

matplotlib.rcParams['axes.unicode_minus'] = False  # 그래프에서 마이너스 기호 표시
warnings.filterwarnings(action='ignore') # 경고 매세지 강제로 없애주는 설정


# dataset load
data = pd.read_csv('./TV_GRPs_by_models.csv')
data = data.drop(['Unnamed: 0'],1)


#preprocessing
# 광고주를 기준으로 광고횟수, GRP, 도달자수, 시청자수를 각각 더함.
idx_ad = data[["Advertiser","GRP","광고횟수","도달자수","시청자수"]].groupby("Advertiser").sum()
# 평균 시청률 
data['평균시청률'] = data['GRP'] / data['광고횟수']
# 평균 노출빈도 구하기 
data['평균노출빈도'] = data['GRP'] / data['도달율 1+']
data['평균노출빈도'].fillna(0, inplace=True)
data['평균노출빈도'].replace(np.inf, 0, inplace=True)
# 광고주와 연령대를 기준으로 그룹화 (평균 기준)
ad_age = data.groupby(["Advertiser", "연령대"]).agg('mean').round(6)[['GRP', '평균시청률', '평균노출빈도']].reset_index()
# 연령대와 광고년도를 기준으로 그룹을 묶어 평균으로 연산 
## 월 행은 삭제 
age_df = data.groupby(['연령대','Year']).mean().round(2).reset_index()
age_df.drop('Month',axis=1,inplace=True)
# 광고주, Product, 연도, 연령대별 광고횟수, GRP, 도달지수, 시청자수
apya = data[["Advertiser","Product","Year","연령대", "광고횟수","GRP","도달자수","시청자수"]].copy().groupby(["Advertiser","Product","Year","연령대"]).mean().reset_index()
apya = apya.astype({"도달자수":int, "시청자수":int})
apya = apya.drop(apya[apya["연령대"]=="개인"].index)

# %%
# graph
from Plot import Plot
plot = Plot()

# 연도별 광고 횟수
plot.countplot(data, "년도", "Year")

# %%
#연령별 GRP, 연령별 평균노출빈도, 연령별 평균시청률
plot.boxplot(ad_age, '연령대', 'GRP', inplacesubplot=131) # inplacesubplot을 설정 O
plot.boxplot(ad_age, '연령대', '평균노출빈도', inplacesubplot=132)
plot.boxplot(ad_age, '연령대', '평균시청률', inplacesubplot=133)
plot.showplot() # inplacesubplot으로 모아서 한번에 출력 가능

# %%
# 브랜드별 광고 횟수
import graph
graph.ad_brand(data, 'Brand')

# %%
# 광고주별 광고횟수, 광고주별 평균시청률
graph.advertiser(data, "Advertiser")

# %%
# 브랜드별 도달자수&시청자수그리프 표현 
fig = px.scatter(idx_ad, 
                 size=idx_ad['GRP'],
                 x=idx_ad['광고횟수'], 
                 y=idx_ad['도달자수'],
                 color=idx_ad.index, 
                 labels={'x':"광고횟수", 'y':"도달자수", 'species':"Brand"})
fig.show();
# Out:
# <div>                            <div id="9eb09336-e5f2-42f0-bb56-925dd334ea96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9eb09336-e5f2-42f0-bb56-925dd334ea96")) {                    Plotly.newPlot(                        "9eb09336-e5f2-42f0-bb56-925dd334ea96",                        [{"hovertemplate": "Advertiser=BMW\ucf54\ub9ac\uc544<br>\uad11\uace0\ud69f\uc218=%{x}<br>\ub3c4\ub2ec\uc790\uc218=%{y}<br>GRP=%{marker.size}<extra></extra>", "legendgroup": "BMW\ucf54\ub9ac\uc544", "marker": {"color": "#636efa", "size": [52573.599999999984], "sizemode": "area", "sizeref": 246.7837500000001, "symbol": "circle"}, "mode": "markers", "name": "BMW\ucf54\ub9ac\uc544", "orientation": "v", "showlegend": true, "type": "scatter", "x": [287898], "xaxis": "x", "y": [982908993], "yaxis": "y"}, {"hovertemplate": "Advertiser=FCA\ucf54\ub9ac\uc544<br>\uad11\uace0\ud69f\uc218=%{x}<br>\ub3c4\ub2ec\uc790\uc218=%{y}<br>GRP=%{marker.size}<extra></extra>", "legendgroup": "FCA\ucf54\ub9ac\uc544", "marker": {"color": "#EF553B", "size": [9257.0], "sizemode": "area", "sizeref": 246.7837500000001, "symbol": "circle"}, "mode": "markers", "name": "FCA\ucf54\ub9ac\uc544", "orientation": "v", "showlegend": true, "type": "scatter", "x": [32268], "xaxis": "x", "y": [147606815], "yaxis": "y"}, {"hovertemplate": "Advertiser=FMK<br>\uad11\uace0\ud69f\uc218=%{x}<br>\ub3c4\ub2ec\uc790\uc218=%{y}<br>GRP=%{marker.size}<extra></extra>", "legendgroup": "FMK", "marker": {"color": "#00cc96", "size": [11642.099999999999], "sizemode": "area", "sizeref": 246.7837500000001, "symbol": "circle"}, "mode": "markers", "name": "FMK", "orientation": "v", "showlegend": true, "type": "scatter", "x": [168012], "xaxis": "x", "y": [261665899], "yaxis": "y"}, {"hovertemplate": "Advertiser=\uae30\ud765\uc778\ud130\ub0b4\uc154\ub110<br>\uad11\uace0\ud69f\uc218=%{x}<br>\ub3c4\ub2ec\uc790\uc218=%{y}<br>GRP=%{marker.size}<extra></extra>", "legendgroup": "\uae30\ud765\uc778\ud130\ub0b4\uc154\ub110", "marker": {"color": "#ab63fa", "size": [469.09999999999997], "sizemode": "area", "sizeref": 246.7837500000001, "symbol": "circle"}, "mode": "markers", "name": "\uae30\ud765\uc778\ud130\ub0b4\uc154\ub110", "orientation": "v", "showlegend": true, "type": "scatter", "x": [108], "xaxis": "x", "y": [11381072], "yaxis": "y"}, {"hovertemplate": "Advertiser=\ub354\ud074\ub798\uc2a4\ud6a8\uc131<br>\uad11\uace0\ud69f\uc218=%{x}<br>\ub3c4\ub2ec\uc790\uc218=%{y}<br>GRP=%{marker.size}<extra></extra>", "legendgroup": "\ub354\ud074\ub798\uc2a4\ud6a8\uc131", "marker": {"color": "#FFA15A", "size": [1209.3], "sizemode": "area", "sizeref": 246.7837500000001, "symbol": "circle"}, "mode": "markers", "name": "\ub354\ud074\ub798\uc2a4\ud6a8\uc131", "orientation": "v", "showlegend": true, "type": "scatter", "x": [4494], "xaxis": "x", "y": [14996504], "yaxis": "y"}, {"hovertemplate": "Advertiser=\ub3c4\uc774\uce58\ubaa8\ud130\uc2a4<br>\uad11\uace0\ud69f\uc218=%{x}<br>\ub3c4\ub2ec\uc790\uc218=%{y}<br>GRP=%{marker.size}<extra></extra>", "legendgroup": "\ub3c4\uc774\uce58\ubaa8\ud130\uc2a4", "marker": {"color": "#19d3f3", "size": [83.9], "sizemode": "area", "sizeref": 246.7837500000001, "symbol": "circle"}, "mode": "markers", "name": "\ub3c4\uc774\uce58\ubaa8\ud130\uc2a4", "orientation": "v", "showlegend": true, "type": "scatter", "x": [30], "xaxis": "x", "y": [1927607], "yaxis": "y"}, {"hovertemplate": "Advertiser=\uba54\ub974\uc138\ub370\uc2a4\ubca4\uce20\ucf54\ub9ac\uc544<br>\uad11\uace0\ud69f\uc218=%{x}<br>\ub3c4\ub2ec\uc790\uc218=%{y}<br>GRP=%{marker.size}<extra></extra>", "legendgroup": "\uba54\ub974\uc138\ub370\uc2a4\ubca4\uce20\ucf54\ub9ac\uc544", "marker": {"color": "#FF6692", "size": [31359.999999999993], "sizemode": "area", "sizeref": 246.7837500000001, "symbol": "circle"}, "mo ...

# %%
# 연령대별 GRP 분포
px.box(data_frame=age_df, x='연령대', y='GRP', title="연령대별 GRP")
# Out:
# <div>                            <div id="88490f91-8f15-4ff3-a139-e136ea135675" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88490f91-8f15-4ff3-a139-e136ea135675")) {                    Plotly.newPlot(                        "88490f91-8f15-4ff3-a139-e136ea135675",                        [{"alignmentgroup": "True", "hovertemplate": "\uc5f0\ub839\ub300=%{x}<br>GRP=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["20\ub300", "20\ub300", "20\ub300", "20\ub300", "20\ub300", "20\ub300", "30\ub300", "30\ub300", "30\ub300", "30\ub300", "30\ub300", "30\ub300", "40\ub300", "40\ub300", "40\ub300", "40\ub300", "40\ub300", "40\ub300", "50\ub300", "50\ub300", "50\ub300", "50\ub300", "50\ub300", "50\ub300", "60\ub300", "60\ub300", "60\ub300", "60\ub300", "60\ub300", "60\ub300", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778"], "x0": " ", "xaxis": "x", "y": [34.85, 35.77, 35.58, 30.07, 42.19, 33.74, 51.44, 71.3, 78.95, 55.86, 71.44, 49.99, 97.31, 121.88, 129.73, 109.66, 139.39, 106.71, 117.22, 125.18, 126.57, 125.49, 163.84, 130.53, 107.74, 106.47, 104.4, 109.98, 145.54, 134.61, 69.94, 84.12, 88.13, 79.62, 105.39, 85.84], "y0": " ", "yaxis": "y"}],                        {"boxmode": "group", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778 ...

# %%
# 연령대별 도달률 1+ 분포
px.box(data_frame=age_df, x='연령대', y='도달율 1+', title="연령대별 도달률 1+")
# Out:
# <div>                            <div id="bcbcdd99-b0fd-4d52-8253-2f8c7e644969" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcbcdd99-b0fd-4d52-8253-2f8c7e644969")) {                    Plotly.newPlot(                        "bcbcdd99-b0fd-4d52-8253-2f8c7e644969",                        [{"alignmentgroup": "True", "hovertemplate": "\uc5f0\ub839\ub300=%{x}<br>\ub3c4\ub2ec\uc728 1+=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["20\ub300", "20\ub300", "20\ub300", "20\ub300", "20\ub300", "20\ub300", "30\ub300", "30\ub300", "30\ub300", "30\ub300", "30\ub300", "30\ub300", "40\ub300", "40\ub300", "40\ub300", "40\ub300", "40\ub300", "40\ub300", "50\ub300", "50\ub300", "50\ub300", "50\ub300", "50\ub300", "50\ub300", "60\ub300", "60\ub300", "60\ub300", "60\ub300", "60\ub300", "60\ub300", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778"], "x0": " ", "xaxis": "x", "y": [13.96, 14.38, 14.58, 11.14, 12.73, 11.8, 17.72, 22.03, 24.74, 17.42, 19.05, 17.61, 26.84, 30.97, 34.25, 26.21, 29.3, 28.12, 30.11, 31.35, 33.16, 28.15, 32.05, 34.3, 26.8, 27.13, 28.32, 24.29, 28.96, 34.66, 20.8, 23.69, 25.73, 20.26, 23.38, 24.27], "y0": " ", "yaxis": "y"}],                        {"boxmode": "group", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, " ...

# %%
# 연령대별 도달률 3+ 분포
px.box(data_frame=age_df, x='연령대', y='도달율 3+', title="연령대별 도달률 3+")
# Out:
# <div>                            <div id="d1d4efbf-fad5-4de6-a93b-e8bbf0069adb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1d4efbf-fad5-4de6-a93b-e8bbf0069adb")) {                    Plotly.newPlot(                        "d1d4efbf-fad5-4de6-a93b-e8bbf0069adb",                        [{"alignmentgroup": "True", "hovertemplate": "\uc5f0\ub839\ub300=%{x}<br>\ub3c4\ub2ec\uc728 3+=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["20\ub300", "20\ub300", "20\ub300", "20\ub300", "20\ub300", "20\ub300", "30\ub300", "30\ub300", "30\ub300", "30\ub300", "30\ub300", "30\ub300", "40\ub300", "40\ub300", "40\ub300", "40\ub300", "40\ub300", "40\ub300", "50\ub300", "50\ub300", "50\ub300", "50\ub300", "50\ub300", "50\ub300", "60\ub300", "60\ub300", "60\ub300", "60\ub300", "60\ub300", "60\ub300", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778"], "x0": " ", "xaxis": "x", "y": [3.8, 4.14, 4.18, 3.57, 4.61, 3.7, 5.87, 8.42, 9.52, 6.55, 7.99, 5.68, 11.22, 14.11, 15.91, 12.48, 15.22, 12.15, 13.19, 14.3, 15.17, 13.72, 17.25, 15.63, 11.63, 11.79, 12.33, 11.6, 15.32, 16.42, 7.86, 9.64, 10.6, 8.85, 11.31, 10.09], "y0": " ", "yaxis": "y"}],                        {"boxmode": "group", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8 ...

# %%
# 연령대별 도달률 5+ 분포
px.box(data_frame=age_df, x='연령대', y='도달율 5+', title="연령대별 도달률 5+")
# Out:
# <div>                            <div id="d36e38d4-be0d-4798-abfd-996fd4b8929a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d36e38d4-be0d-4798-abfd-996fd4b8929a")) {                    Plotly.newPlot(                        "d36e38d4-be0d-4798-abfd-996fd4b8929a",                        [{"alignmentgroup": "True", "hovertemplate": "\uc5f0\ub839\ub300=%{x}<br>\ub3c4\ub2ec\uc728 5+=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["20\ub300", "20\ub300", "20\ub300", "20\ub300", "20\ub300", "20\ub300", "30\ub300", "30\ub300", "30\ub300", "30\ub300", "30\ub300", "30\ub300", "40\ub300", "40\ub300", "40\ub300", "40\ub300", "40\ub300", "40\ub300", "50\ub300", "50\ub300", "50\ub300", "50\ub300", "50\ub300", "50\ub300", "60\ub300", "60\ub300", "60\ub300", "60\ub300", "60\ub300", "60\ub300", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778", "\uac1c\uc778"], "x0": " ", "xaxis": "x", "y": [1.61, 1.8, 1.73, 1.62, 2.37, 1.84, 2.82, 4.42, 4.85, 3.39, 4.33, 2.72, 6.07, 8.08, 8.77, 7.15, 9.22, 6.84, 7.3, 8.28, 8.4, 8.05, 10.74, 8.57, 6.59, 6.69, 6.82, 6.87, 9.48, 9.03, 4.1, 5.27, 5.59, 4.95, 6.72, 5.41], "y0": " ", "yaxis": "y"}],                        {"boxmode": "group", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "# ...

# %%
#(광고주)시청자별 도달지수
fig = px.scatter(apya, 
                 size=apya['GRP'],
                 y='도달자수', 
                 x='시청자수',
                 color='Advertiser', 
                 labels={'x':"시청자수",'y':"도달자수"})
fig.show()
# Out:
# <div>                            <div id="3e48eff2-fa89-452b-8d1d-c264ef521026" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e48eff2-fa89-452b-8d1d-c264ef521026")) {                    Plotly.newPlot(                        "3e48eff2-fa89-452b-8d1d-c264ef521026",                        [{"hovertemplate": "Advertiser=BMW\ucf54\ub9ac\uc544<br>\uc2dc\uccad\uc790\uc218=%{x}<br>\ub3c4\ub2ec\uc790\uc218=%{y}<br>GRP=%{marker.size}<extra></extra>", "legendgroup": "BMW\ucf54\ub9ac\uc544", "marker": {"color": "#636efa", "size": [31.560000000000002, 61.31999999999999, 110.98000000000002, 107.38, 79.61999999999999, 33.35, 59.8, 111.97500000000001, 116.5, 103.725, 36.650000000000006, 40.4, 78.85, 121.9, 136.25, 45.175, 109.8, 173.225, 142.025, 102.975, 8.6, 16.85, 37.75, 33.7, 25.05, 34.5, 73.8, 108.6, 95.1, 60.05, 1.4, 1.8, 4.8, 5.4, 2.2, 18.1, 36.35, 57.5, 70.25, 55.05, 14.625, 26.125, 52.15, 49.324999999999996, 30.375, 48.26666666666667, 88.76666666666667, 149.16666666666666, 152.7, 119.86666666666667, 1.2, 0.6, 2.2, 3.1, 1.4, 29.8, 57.4, 84.5, 100.1, 50.4, 20.0, 32.7, 57.3, 67.5, 45.9, 100.44999999999999, 176.15, 347.95, 361.55, 301.2, 86.40000000000002, 141.0, 238.33333333333334, 340.2, 255.36666666666665, 14.35, 40.15, 57.55, 43.8, 30.799999999999997, 107.8, 206.20000000000002, 352.76666666666665, 318.85, 221.85, 68.25, 102.3, 203.5, 245.6, 199.65, 64.2, 145.0, 215.0, 147.05, 109.94999999999999, 26.333333333333332, 61.43333333333334, 84.60000000000001, 65.01666666666667, 45.13333333333333, 76.06666666666666, 185.26666666666668, 285.1333333333334, 265.1333333333333, 192.56666666666663, 58.175, 109.525, 181.47500000000002, 173.925, 137.75, 34.3, 61.099999999999994, 105.52499999999999, 123.45, 122.45000000000002, 36.46666666666667, 59.522222222222226, 109.6, 151.0222222222222, 141.24444444444444, 23.75, 54.2, 101.35000000000001, 97.0, 71.30000000000001, 38.8, 66.35000000000001, 154.7, 194.475, 210.825], "sizemode": "area", "sizeref": 2.93425, "symbol": "circle"}, "mode": "markers", "name": "BMW\ucf54\ub9ac\uc544", "showlegend": true, "type": "scattergl", "x": [1069815, 2328816, 4713253, 4260110, 3606191, 1106083, 2350537, 4819367, 4515660, 4213206, 1269159, 1674242, 3250555, 3790796, 4280452, 1510816, 4244115, 7407576, 5581240, 4413085, 294466, 633966, 1573569, 1357549, 1200482, 1143687, 2900527, 4676241, 3684564, 2438732, 46406, 68386, 202937, 213168, 101771, 619464, 1365633, 2398895, 2832828, 2635313, 495189, 992421, 2215540, 1956612, 1376046, 1614475, 3432565, 6379026, 6000011, 5136925, 39757, 21273, 94067, 122550, 61361, 1030477, 2379949, 3483242, 3112290, 1584016, 663734, 1285530, 2466915, 2617882, 1865368, 3436821, 6620075, 14513256, 14574390, 14420836, 2992006, 5847850, 9824880, 10578042, 8023810, 478564, 1552435, 2461079, 1719733, 1320582, 3574335, 8104719, 15186015, 12359879, 9010608, 2334184, 3845663, 8489547, 9902795, 9560013, 2147278, 5604555, 9193477, 5777429, 4712395, 912157, 2547933, 3487818, 2022079, 1417579, 2542769, 7162267, 12192525, 10419726, 8252498, 1927717, 4304949, 7812575, 6741922, 5594737, 1173745, 2296064, 4401682, 4976560, 5864706, 1262071, 2468017, 4518929, 4696451, 4437609, 787422, 2130013, 4361911, 3759626, 2894059, 1315836, 2520563, 6572772, 7715001, 9553151], "xaxis": "x", "y": [380731, 785572, 1206770, 1192444, 1070082, 460419, 841315, 1305883, 1217249, 1189944, 440869, 448995, 887682, 934869, 896056, 530490, 1154424, 1762167, 1451605, 1325358, 216557, 455459, 816289, 796464, 709997, 593316, 1106077, 1685044, 1434560, 1167650, 23203, 34193, 119088, 106584, 55294, 326691, 579549, 933662, 943730, 989539, 255024, 479815, 947673, 843636, 603737, 627131, 1151085, 1737145, 1507293, 1434724, 39757, 21273, 94067, 122550, 61361, 481829, 1000337, 1310609, 1034402, 731470, 43 ...

# %%
[
    
    #(광고주,연령대)광고횟수별 도달지수
fig = px.scatter(apya, x="광고횟수", y="도달자수", animation_frame="Year", animation_group="Advertiser",
           size="GRP", color="Advertiser", hover_name="Advertiser", facet_col="연령대",
           size_max=30, range_x=[-100, 2500], range_y=[1,4000000])
fig.show()
# Out:
# <div>                            <div id="2e68e258-56a2-4c90-8399-3ccabb6adb92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e68e258-56a2-4c90-8399-3ccabb6adb92")) {                    Plotly.newPlot(                        "2e68e258-56a2-4c90-8399-3ccabb6adb92",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Advertiser=BMW\ucf54\ub9ac\uc544<br>Year=2019<br>\uc5f0\ub839\ub300=20\ub300<br>\uad11\uace0\ud69f\uc218=%{x}<br>\ub3c4\ub2ec\uc790\uc218=%{y}<br>GRP=%{marker.size}<extra></extra>", "hovertext": ["BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544"], "ids": ["BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544"], "legendgroup": "BMW\ucf54\ub9ac\uc544", "marker": {"color": "#636efa", "size": [31.560000000000002, 1.4, 14.625, 1.2, 38.8], "sizemode": "area", "sizeref": 1.3041111111111112, "symbol": "circle"}, "mode": "markers", "name": "BMW\ucf54\ub9ac\uc544", "orientation": "v", "showlegend": true, "type": "scatter", "x": [814.4, 2.0, 394.25, 1.0, 262.5], "xaxis": "x", "y": [380731, 23203, 255024, 39757, 560785], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Advertiser=BMW\ucf54\ub9ac\uc544<br>Year=2019<br>\uc5f0\ub839\ub300=30\ub300<br>\uad11\uace0\ud69f\uc218=%{x}<br>\ub3c4\ub2ec\uc790\uc218=%{y}<br>GRP=%{marker.size}<extra></extra>", "hovertext": ["BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544"], "ids": ["BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544"], "legendgroup": "BMW\ucf54\ub9ac\uc544", "marker": {"color": "#636efa", "size": [61.31999999999999, 1.8, 26.125, 0.6, 66.35000000000001], "sizemode": "area", "sizeref": 1.3041111111111112, "symbol": "circle"}, "mode": "markers", "name": "BMW\ucf54\ub9ac\uc544", "orientation": "v", "showlegend": false, "type": "scatter", "x": [814.4, 2.0, 394.25, 1.0, 262.5], "xaxis": "x2", "y": [785572, 34193, 479815, 21273, 934778], "yaxis": "y2"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Advertiser=BMW\ucf54\ub9ac\uc544<br>Year=2019<br>\uc5f0\ub839\ub300=40\ub300<br>\uad11\uace0\ud69f\uc218=%{x}<br>\ub3c4\ub2ec\uc790\uc218=%{y}<br>GRP=%{marker.size}<extra></extra>", "hovertext": ["BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544"], "ids": ["BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544"], "legendgroup": "BMW\ucf54\ub9ac\uc544", "marker": {"color": "#636efa", "size": [110.98000000000002, 4.8, 52.15, 2.2, 154.7], "sizemode": "area", "sizeref": 1.3041111111111112, "symbol": "circle"}, "mode": "markers", "name": "BMW\ucf54\ub9ac\uc544", "orientation": "v", "showlegend": false, "type": "scatter", "x": [814.4, 2.0, 394.25, 1.0, 262.5], "xaxis": "x3", "y": [1206770, 119088, 947673, 94067, 1552184], "yaxis": "y3"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Advertiser=BMW\ucf54\ub9ac\uc544<br>Year=2019<br>\uc5f0\ub839\ub300=50\ub300<br>\uad11\uace0\ud69f\uc218=%{x}<br>\ub3c4\ub2ec\uc790\uc218=%{y}<br>GRP=%{marker.size}<extra></extra>", "hovertext": ["BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544"], "ids": ["BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544", "BMW\ucf54\ub9ac\uc544"], "legendgroup": "BMW\ucf54\ub9ac\uc544", "marker": {"color": "#636efa", "size": [107.38, 5.4, 49.324999999999996, 3.1, 194.475], "sizemode": "area", "sizeref": 1.3041111111111112 ...
